# %% [markdown]
# <a href="https://colab.research.google.com/github/jjbmsda/Paper/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torch.nn

# %%
torch.cuda.is_available()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Paper/

# %%
# !python train.py

# %%
# !python test.py
